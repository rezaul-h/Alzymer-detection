# %%
# !pip install split-folders
# !pip install scikit-image
# !pip install keras-tuner

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

import os
from distutils.dir_util import copy_tree, remove_tree

from PIL import Image
from random import randint

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import *
from sklearn.metrics import classification_report, confusion_matrix

# import tensorflow_addons as tfa
# from keras.utils.vis_utils import plot_model
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.callbacks import *
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.layers import SeparableConv2D, BatchNormalization, GlobalAveragePooling2D


print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.4.0

# %%
categories = ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

# %%
base_dir = "F:\\Ml files\\Alzymer detection/Alzheimer_s Dataset/"
root_dir = "./"
test_dir = base_dir + "test/"
train_dir = base_dir + "train/"
work_dir = root_dir + "dataset/"

if os.path.exists(work_dir):
    remove_tree(work_dir)
    

os.mkdir(work_dir)
copy_tree(train_dir, work_dir)
copy_tree(test_dir, work_dir)
print("Working Directory Contents:", os.listdir(work_dir))
# Out:
# Working Directory Contents: ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

# %%
WORK_DIR = './dataset/'

CLASSES = [ 'NonDemented',
            'VeryMildDemented',
            'MildDemented',
            'ModerateDemented']

IMG_SIZE = 224
IMAGE_SIZE = [224, 224]
DIM = (IMG_SIZE, IMG_SIZE)

# %%
#Performing Image Augmentation to have more data samples

ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

work_dr = IDG(rescale = 1./255, brightness_range=BRIGHT_RANGE, zoom_range=ZOOM, data_format=DATA_FORMAT, fill_mode=FILL_MODE, horizontal_flip=HORZ_FLIP)

train_data_gen = work_dr.flow_from_directory(directory=WORK_DIR, target_size=DIM, batch_size=6500, shuffle=False)
# Out:
# Found 6400 images belonging to 4 classes.

# %%
def show_images(generator,y_pred=None):
    """
    Input: An image generator,predicted labels (optional)
    Output: Displays a grid of 9 images with lables
    """
    
    # get image lables
    labels =dict(zip([0,1,2,3], CLASSES))
    
    # get a batch of images
    x,y = generator.next()
    
    # display a grid of 9 images
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 6400)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Class:{}".format(labels[np.argmax(y[idx])]))
                                                     
    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))
    
# Display Train Images
show_images(train_data_gen)

# %%
#Retrieving the data from the ImageDataGenerator iterator

train_data, train_labels = train_data_gen.next()

# %%
#Getting to know the dimensions of our dataset

print(train_data.shape, train_labels.shape)
# Out:
# (6400, 224, 224, 3) (6400, 4)

# %%
#Performing over-sampling of the data, since the classes are imbalanced

sm = SMOTE(random_state=42)

train_data, train_labels = sm.fit_resample(train_data.reshape(-1, IMG_SIZE * IMG_SIZE * 3), train_labels)

train_data = train_data.reshape(-1, IMG_SIZE, IMG_SIZE, 3)

print(train_data.shape, train_labels.shape)
# Out:
# (12800, 224, 224, 3) (12800, 4)

# %%
#Splitting the data into train, test, and validation sets

train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

# %%
from tensorflow.keras.applications.densenet import DenseNet121

base_model=DenseNet121(weights='imagenet',include_top=False,input_shape = (224, 224, 3))
DenseNet121_model = Sequential([
        base_model,
        Dropout(0.5),
        GlobalAveragePooling2D(),
        Flatten(),
        BatchNormalization(),
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(64, activation='relu'),
        Dropout(0.5),
        BatchNormalization(),
        Dense(4, activation='softmax')
    ])

# %%
#Defining a custom callback function to stop training our model when accuracy goes above 99%

class MyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('acc') > 0.99:
            print("\nReached accuracy threshold! Terminating training.")
            self.model.stop_training = True
            
my_callback = MyCallback()

#ReduceLROnPlateau to stabilize the training process of the model
rop_callback = ReduceLROnPlateau(monitor="val_loss", patience=3)
checkpoint_path = 'F:\\Ml files\\Alzymer detection\\model\\kfold-DenseNet121-class_11.h5'
saved_model = ModelCheckpoint(monitor='val_loss', mode='min', filepath=checkpoint_path, verbose=1, save_best_only=True, save_weights_only=False)

# %%
METRICS = [tf.keras.metrics.CategoricalAccuracy(name='acc'),
           tf.keras.metrics.AUC(name='auc')]

CALLBACKS = [my_callback, rop_callback,saved_model]
    
DenseNet121_model.compile(optimizer='rmsprop',
                              loss='categorical_crossentropy',
                              metrics=METRICS)

DenseNet121_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Functional)     (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dense (Dense)                (None, 512)               524800
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 7,742,980
# Trainable params: 7,655,364
# Non-trainable params: 87,616
# _________________________________________________________________

# %%
#Fit the training data to the model and validate it using the validation data
EPOCHS = 100


history = DenseNet121_model.fit(train_data, train_labels, validation_data=(val_data, val_labels), callbacks=CALLBACKS, epochs=EPOCHS)
# Out:
# Epoch 1/100
# 256/256 [==============================] - 115s 269ms/step - loss: 1.8054 - acc: 0.2629 - auc: 0.5128 - val_loss: 1.4219 - val_acc: 0.2573 - val_auc: 0.5020
#
# Epoch 00001: val_loss improved from inf to 1.42194, saving model to F:\Ml files\Alzymer detection\model\kfold-DenseNet121-class_11.h5
# Epoch 2/100
# 256/256 [==============================] - 67s 263ms/step - loss: 1.5132 - acc: 0.2615 - auc: 0.5243 - val_loss: 1.7084 - val_acc: 0.2607 - val_auc: 0.5062
#
# Epoch 00002: val_loss did not improve from 1.42194
# Epoch 3/100
# 256/256 [==============================] - 67s 264ms/step - loss: 1.3704 - acc: 0.3173 - auc: 0.5890 - val_loss: 34.4268 - val_acc: 0.2285 - val_auc: 0.4838
#
# Epoch 00003: val_loss did not improve from 1.42194
# Epoch 4/100
# 256/256 [==============================] - 67s 263ms/step - loss: 0.9890 - acc: 0.5578 - auc: 0.8239 - val_loss: 0.8806 - val_acc: 0.6406 - val_auc: 0.8851
#
# Epoch 00004: val_loss improved from 1.42194 to 0.88060, saving model to F:\Ml files\Alzymer detection\model\kfold-DenseNet121-class_11.h5
# Epoch 5/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.8085 - acc: 0.6480 - auc: 0.8838 - val_loss: 1.3573 - val_acc: 0.4849 - val_auc: 0.8023
#
# Epoch 00005: val_loss did not improve from 0.88060
# Epoch 6/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.7174 - acc: 0.6796 - auc: 0.9058 - val_loss: 1.4263 - val_acc: 0.5044 - val_auc: 0.7861
#
# Epoch 00006: val_loss did not improve from 0.88060
# Epoch 7/100
# 256/256 [==============================] - 67s 263ms/step - loss: 0.6724 - acc: 0.6999 - auc: 0.9182 - val_loss: 2.5715 - val_acc: 0.4927 - val_auc: 0.7763
#
# Epoch 00007: val_loss did not improve from 0.88060
# Epoch 8/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.5944 - acc: 0.7357 - auc: 0.9367 - val_loss: 0.5319 - val_acc: 0.7632 - val_auc: 0.9487
#
# Epoch 00008: val_loss improved from 0.88060 to 0.53191, saving model to F:\Ml files\Alzymer detection\model\kfold-DenseNet121-class_11.h5
# Epoch 9/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.5258 - acc: 0.7700 - auc: 0.9503 - val_loss: 0.5900 - val_acc: 0.7344 - val_auc: 0.9342
#
# Epoch 00009: val_loss did not improve from 0.53191
# Epoch 10/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.5040 - acc: 0.7866 - auc: 0.9548 - val_loss: 0.4877 - val_acc: 0.7910 - val_auc: 0.9561
#
# Epoch 00010: val_loss improved from 0.53191 to 0.48770, saving model to F:\Ml files\Alzymer detection\model\kfold-DenseNet121-class_11.h5
# Epoch 11/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.4768 - acc: 0.8024 - auc: 0.9593 - val_loss: 0.4834 - val_acc: 0.7939 - val_auc: 0.9562
#
# Epoch 00011: val_loss improved from 0.48770 to 0.48339, saving model to F:\Ml files\Alzymer detection\model\kfold-DenseNet121-class_11.h5
# Epoch 12/100
# 256/256 [==============================] - 67s 263ms/step - loss: 0.4740 - acc: 0.8037 - auc: 0.9596 - val_loss: 0.5499 - val_acc: 0.7573 - val_auc: 0.9454
#
# Epoch 00012: val_loss did not improve from 0.48339
# Epoch 13/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.4315 - acc: 0.8185 - auc: 0.9664 - val_loss: 0.7242 - val_acc: 0.6816 - val_auc: 0.9190
#
# Epoch 00013: val_loss did not improve from 0.48339
# Epoch 14/100
# 256/256 [==============================] - 70s 274ms/step - loss: 0.4077 - acc: 0.8354 - auc: 0.9697 - val_loss: 0.4367 - val_acc: 0.8037 - val_auc: 0.9639
#
# Epoch 00014: val_loss improved from 0.48339 to 0.43672, saving model to F:\Ml files\Alzymer detection\model\kfold-DenseNet121-class_11.h5
# Epoch 15/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.4054 - acc: 0.8369 - auc: 0.9701 - val_loss: 0.4349 - val_acc: 0.8101 - val_auc: 0.9648
#
# Epoch 00015: val_loss improved from 0.43672 to 0.43494, saving model to F:\Ml files\Alzymer detection\model\kfold-DenseNet121-class_11.h5
# Epoch 16/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.3714 - acc: 0.8502 - auc: 0.9748 - val_loss: 0.4284 - val_acc: 0.8135 - val_auc: 0.9660
#
# Epoch 00016: val_loss improved from 0.43494 to 0.42845, saving model to F:\Ml files\Alzymer detection\model\kfold-DenseNet121-class_11.h5
# Epoch 17/100
# 256/256 [==============================] - 69s 269ms/step - loss: 0.3607 - acc: 0.8541 - auc: 0.9759 - val_loss: 0.3691 - val_acc: 0.8472 - val_auc: 0.9742
#
# Epoch 00017: val_loss improved from 0.42845 to 0.36908, saving model to F:\Ml files\Alzymer detection\model\kfold-DenseNet121-class_11.h5
# Epoch 18/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.3362 - acc: 0.8706 - auc: 0.9791 - val_loss: 0.4001 - val_acc: 0.8291 - val_auc: 0.9704
#
# Epoch 00018: val_loss did not improve from 0.36908
# Epoch 19/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.3290 - acc: 0.8718 - auc: 0.9800 - val_loss: 0.3885 - val_acc: 0.8345 - val_auc: 0.9726
#
# Epoch 00019: val_loss did not improve from 0.36908
# Epoch 20/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.3170 - acc: 0.8797 - auc: 0.9812 - val_loss: 0.3535 - val_acc: 0.8550 - val_auc: 0.9765
#
# Epoch 00020: val_loss improved from 0.36908 to 0.35346, saving model to F:\Ml files\Alzymer detection\model\kfold-DenseNet121-class_11.h5
# Epoch 21/100
# 256/256 [==============================] - 68s 266ms/step - loss: 0.3045 - acc: 0.8853 - auc: 0.9824 - val_loss: 0.3611 - val_acc: 0.8506 - val_auc: 0.9765
#
# Epoch 00021: val_loss did not improve from 0.35346
# Epoch 22/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.3055 - acc: 0.8909 - auc: 0.9821 - val_loss: 0.5683 - val_acc: 0.7754 - val_auc: 0.9538
#
# Epoch 00022: val_loss did not improve from 0.35346
# Epoch 23/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2670 - acc: 0.9040 - auc: 0.9860 - val_loss: 0.3599 - val_acc: 0.8535 - val_auc: 0.9771
#
# Epoch 00023: val_loss did not improve from 0.35346
# Epoch 24/100
# 256/256 [==============================] - 67s 263ms/step - loss: 0.2403 - acc: 0.9174 - auc: 0.9890 - val_loss: 0.3115 - val_acc: 0.8745 - val_auc: 0.9816
#
# Epoch 00024: val_loss improved from 0.35346 to 0.31147, saving model to F:\Ml files\Alzymer detection\model\kfold-DenseNet121-class_11.h5
# Epoch 25/100
# 256/256 [==============================] - 67s 263ms/step - loss: 0.2104 - acc: 0.9294 - auc: 0.9920 - val_loss: 0.3009 - val_acc: 0.8755 - val_auc: 0.9828
#
# Epoch 00025: val_loss improved from 0.31147 to 0.30091, saving model to F:\Ml files\Alzymer detection\model\kfold-DenseNet121-class_11.h5
# Epoch 26/100
# 256/256 [==============================] - 67s 263ms/step - loss: 0.2080 - acc: 0.9290 - auc: 0.9923 - val_loss: 0.3048 - val_acc: 0.8784 - val_auc: 0.9826
#
# Epoch 00026: val_loss did not improve from 0.30091
# Epoch 27/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.2296 - acc: 0.9236 - auc: 0.9896 - val_loss: 0.3010 - val_acc: 0.8779 - val_auc: 0.9831
#
# Epoch 00027: val_loss did not improve from 0.30091
# Epoch 28/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2298 - acc: 0.9210 - auc: 0.9898 - val_loss: 0.3090 - val_acc: 0.8760 - val_auc: 0.9822
#
# Epoch 00028: val_loss did not improve from 0.30091
# Epoch 29/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.1994 - acc: 0.9350 - auc: 0.9929 - val_loss: 0.2996 - val_acc: 0.8804 - val_auc: 0.9834
#
# Epoch 00029: val_loss improved from 0.30091 to 0.29964, saving model to F:\Ml files\Alzymer detection\model\kfold-DenseNet121-class_11.h5
# Epoch 30/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2078 - acc: 0.9307 - auc: 0.9917 - val_loss: 0.2981 - val_acc: 0.8794 - val_auc: 0.9835
#
# Epoch 00030: val_loss improved from 0.29964 to 0.29807, saving model to F:\Ml files\Alzymer detection\model\kfold-DenseNet121-class_11.h5
# Epoch 31/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2004 - acc: 0.9348 - auc: 0.9923 - val_loss: 0.2987 - val_acc: 0.8794 - val_auc: 0.9837
#
# Epoch 00031: val_loss did not improve from 0.29807
# Epoch 32/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.1848 - acc: 0.9436 - auc: 0.9939 - val_loss: 0.2986 - val_acc: 0.8794 - val_auc: 0.9837
# Epoch 00032: val_loss did not improve from 0.29807
# Epoch 33/100
# 256/256 [==============================] - 67s 263ms/step - loss: 0.1958 - acc: 0.9350 - auc: 0.9931 - val_loss: 0.2993 - val_acc: 0.8804 - val_auc: 0.9835
#
# Epoch 00033: val_loss did not improve from 0.29807
# Epoch 34/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2248 - acc: 0.9228 - auc: 0.9901 - val_loss: 0.3007 - val_acc: 0.8809 - val_auc: 0.9833
#
# Epoch 00034: val_loss did not improve from 0.29807
# Epoch 35/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2094 - acc: 0.9258 - auc: 0.9921 - val_loss: 0.2990 - val_acc: 0.8799 - val_auc: 0.9835
#
# Epoch 00035: val_loss did not improve from 0.29807
# Epoch 36/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.1941 - acc: 0.9422 - auc: 0.9929 - val_loss: 0.2994 - val_acc: 0.8804 - val_auc: 0.9834
#
# Epoch 00036: val_loss did not improve from 0.29807
# Epoch 37/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.2111 - acc: 0.9266 - auc: 0.9916 - val_loss: 0.2996 - val_acc: 0.8789 - val_auc: 0.9836
#
# Epoch 00037: val_loss did not improve from 0.29807
# Epoch 38/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2154 - acc: 0.9261 - auc: 0.9912 - val_loss: 0.2996 - val_acc: 0.8799 - val_auc: 0.9836
#
# Epoch 00038: val_loss did not improve from 0.29807
# Epoch 39/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.2200 - acc: 0.9252 - auc: 0.9904 - val_loss: 0.2995 - val_acc: 0.8813 - val_auc: 0.9835
#
# Epoch 00039: val_loss did not improve from 0.29807
# Epoch 40/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.2069 - acc: 0.9293 - auc: 0.9921 - val_loss: 0.2988 - val_acc: 0.8813 - val_auc: 0.9838
#
# Epoch 00040: val_loss did not improve from 0.29807
# Epoch 41/100
# 256/256 [==============================] - 67s 263ms/step - loss: 0.2015 - acc: 0.9338 - auc: 0.9924 - val_loss: 0.2995 - val_acc: 0.8804 - val_auc: 0.9836
#
# Epoch 00041: val_loss did not improve from 0.29807
# Epoch 42/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.2039 - acc: 0.9335 - auc: 0.9921 - val_loss: 0.3010 - val_acc: 0.8823 - val_auc: 0.9832
#
# Epoch 00042: val_loss did not improve from 0.29807
# Epoch 43/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2015 - acc: 0.9314 - auc: 0.9925 - val_loss: 0.2998 - val_acc: 0.8809 - val_auc: 0.9835
#
# Epoch 00043: val_loss did not improve from 0.29807
# Epoch 44/100
# 256/256 [==============================] - 67s 263ms/step - loss: 0.2099 - acc: 0.9339 - auc: 0.9916 - val_loss: 0.2992 - val_acc: 0.8799 - val_auc: 0.9835
#
# Epoch 00044: val_loss did not improve from 0.29807
# Epoch 45/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2182 - acc: 0.9219 - auc: 0.9908 - val_loss: 0.2994 - val_acc: 0.8794 - val_auc: 0.9835
#
# Epoch 00045: val_loss did not improve from 0.29807
# Epoch 46/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2042 - acc: 0.9330 - auc: 0.9924 - val_loss: 0.3003 - val_acc: 0.8809 - val_auc: 0.9835
#
# Epoch 00046: val_loss did not improve from 0.29807
# Epoch 47/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.1997 - acc: 0.9298 - auc: 0.9927 - val_loss: 0.2996 - val_acc: 0.8804 - val_auc: 0.9835
#
# Epoch 00047: val_loss did not improve from 0.29807
# Epoch 48/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.2097 - acc: 0.9345 - auc: 0.9918 - val_loss: 0.2991 - val_acc: 0.8794 - val_auc: 0.9836
#
# Epoch 00048: val_loss did not improve from 0.29807
# Epoch 49/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.1956 - acc: 0.9347 - auc: 0.9930 - val_loss: 0.2989 - val_acc: 0.8794 - val_auc: 0.9838
#
# Epoch 00049: val_loss did not improve from 0.29807
# Epoch 50/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.2036 - acc: 0.9336 - auc: 0.9924 - val_loss: 0.2995 - val_acc: 0.8799 - val_auc: 0.9834
#
# Epoch 00050: val_loss did not improve from 0.29807
# Epoch 51/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.1951 - acc: 0.9364 - auc: 0.9931 - val_loss: 0.2988 - val_acc: 0.8809 - val_auc: 0.9837
#
# Epoch 00051: val_loss did not improve from 0.29807
# Epoch 52/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.1929 - acc: 0.9366 - auc: 0.9931 - val_loss: 0.2989 - val_acc: 0.8804 - val_auc: 0.9836
#
# Epoch 00052: val_loss did not improve from 0.29807
# Epoch 53/100
# 256/256 [==============================] - 67s 263ms/step - loss: 0.2072 - acc: 0.9291 - auc: 0.9922 - val_loss: 0.2983 - val_acc: 0.8804 - val_auc: 0.9835
#
# Epoch 00053: val_loss did not improve from 0.29807
# Epoch 54/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.2002 - acc: 0.9347 - auc: 0.9926 - val_loss: 0.2996 - val_acc: 0.8813 - val_auc: 0.9835
#
# Epoch 00054: val_loss did not improve from 0.29807
# Epoch 55/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2139 - acc: 0.9319 - auc: 0.9912 - val_loss: 0.2983 - val_acc: 0.8799 - val_auc: 0.9837
#
# Epoch 00055: val_loss did not improve from 0.29807
# Epoch 56/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.1999 - acc: 0.9322 - auc: 0.9925 - val_loss: 0.3001 - val_acc: 0.8809 - val_auc: 0.9833
#
# Epoch 00056: val_loss did not improve from 0.29807
# Epoch 57/100
# 256/256 [==============================] - 68s 266ms/step - loss: 0.2013 - acc: 0.9360 - auc: 0.9924 - val_loss: 0.2992 - val_acc: 0.8794 - val_auc: 0.9833
#
# Epoch 00057: val_loss did not improve from 0.29807
# Epoch 58/100
# 256/256 [==============================] - 67s 263ms/step - loss: 0.2321 - acc: 0.9287 - auc: 0.9893 - val_loss: 0.2997 - val_acc: 0.8799 - val_auc: 0.9833
#
# Epoch 00058: val_loss did not improve from 0.29807
# Epoch 59/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.1998 - acc: 0.9345 - auc: 0.9926 - val_loss: 0.3003 - val_acc: 0.8799 - val_auc: 0.9835
#
# Epoch 00059: val_loss did not improve from 0.29807
# Epoch 60/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.1929 - acc: 0.9385 - auc: 0.9931 - val_loss: 0.3002 - val_acc: 0.8804 - val_auc: 0.9833
#
# Epoch 00060: val_loss did not improve from 0.29807
# Epoch 61/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2070 - acc: 0.9311 - auc: 0.9921 - val_loss: 0.2986 - val_acc: 0.8794 - val_auc: 0.9838
#
# Epoch 00061: val_loss did not improve from 0.29807
# Epoch 62/100
# 256/256 [==============================] - 67s 263ms/step - loss: 0.1839 - acc: 0.9378 - auc: 0.9942 - val_loss: 0.2981 - val_acc: 0.8794 - val_auc: 0.9838
#
# Epoch 00062: val_loss did not improve from 0.29807
# Epoch 63/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2066 - acc: 0.9335 - auc: 0.9916 - val_loss: 0.2992 - val_acc: 0.8809 - val_auc: 0.9835
#
# Epoch 00063: val_loss did not improve from 0.29807
# Epoch 64/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2002 - acc: 0.9323 - auc: 0.9926 - val_loss: 0.2998 - val_acc: 0.8799 - val_auc: 0.9835
#
# Epoch 00064: val_loss did not improve from 0.29807
# Epoch 65/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.2040 - acc: 0.9325 - auc: 0.9922 - val_loss: 0.2985 - val_acc: 0.8794 - val_auc: 0.9837
#
# Epoch 00065: val_loss did not improve from 0.29807
# Epoch 66/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.1992 - acc: 0.9384 - auc: 0.9925 - val_loss: 0.3009 - val_acc: 0.8818 - val_auc: 0.9833
#
# Epoch 00066: val_loss did not improve from 0.29807
# Epoch 67/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2127 - acc: 0.9256 - auc: 0.9918 - val_loss: 0.3003 - val_acc: 0.8804 - val_auc: 0.9832
#
# Epoch 00067: val_loss did not improve from 0.29807
# Epoch 68/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.2043 - acc: 0.9377 - auc: 0.9921 - val_loss: 0.3003 - val_acc: 0.8799 - val_auc: 0.9833
#
# Epoch 00068: val_loss did not improve from 0.29807
# Epoch 69/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.2094 - acc: 0.9346 - auc: 0.9913 - val_loss: 0.3000 - val_acc: 0.8809 - val_auc: 0.9835
#
# Epoch 00069: val_loss did not improve from 0.29807
# Epoch 70/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.2014 - acc: 0.9324 - auc: 0.9927 - val_loss: 0.2983 - val_acc: 0.8784 - val_auc: 0.9837
#
# Epoch 00070: val_loss did not improve from 0.29807
# Epoch 71/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.2151 - acc: 0.9298 - auc: 0.9909 - val_loss: 0.2996 - val_acc: 0.8804 - val_auc: 0.9835
#
# Epoch 00071: val_loss did not improve from 0.29807
# Epoch 72/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.1997 - acc: 0.9378 - auc: 0.9928 - val_loss: 0.2987 - val_acc: 0.8794 - val_auc: 0.9836
#
# Epoch 00072: val_loss did not improve from 0.29807
# Epoch 73/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.1964 - acc: 0.9376 - auc: 0.9931 - val_loss: 0.2987 - val_acc: 0.8799 - val_auc: 0.9838
#
# Epoch 00073: val_loss did not improve from 0.29807
# Epoch 74/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.1897 - acc: 0.9366 - auc: 0.9937 - val_loss: 0.2999 - val_acc: 0.8809 - val_auc: 0.9835
#
# Epoch 00074: val_loss did not improve from 0.29807
# Epoch 75/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2098 - acc: 0.9299 - auc: 0.9915 - val_loss: 0.2996 - val_acc: 0.8804 - val_auc: 0.9835
#
# Epoch 00075: val_loss did not improve from 0.29807
# Epoch 76/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.2046 - acc: 0.9347 - auc: 0.9923 - val_loss: 0.2991 - val_acc: 0.8799 - val_auc: 0.9836
#
# Epoch 00076: val_loss did not improve from 0.29807
# Epoch 77/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.2133 - acc: 0.9279 - auc: 0.9912 - val_loss: 0.2995 - val_acc: 0.8799 - val_auc: 0.9835
#
# Epoch 00077: val_loss did not improve from 0.29807
# Epoch 78/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.1897 - acc: 0.9403 - auc: 0.9934 - val_loss: 0.2990 - val_acc: 0.8799 - val_auc: 0.9835
#
# Epoch 00078: val_loss did not improve from 0.29807
# Epoch 79/100
# 256/256 [==============================] - 67s 263ms/step - loss: 0.2150 - acc: 0.9250 - auc: 0.9913 - val_loss: 0.2990 - val_acc: 0.8799 - val_auc: 0.9836
#
# Epoch 00079: val_loss did not improve from 0.29807
# Epoch 80/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2090 - acc: 0.9276 - auc: 0.9916 - val_loss: 0.3003 - val_acc: 0.8809 - val_auc: 0.9833
#
# Epoch 00080: val_loss did not improve from 0.29807
# Epoch 81/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.1988 - acc: 0.9354 - auc: 0.9928 - val_loss: 0.2990 - val_acc: 0.8794 - val_auc: 0.9835
#
# Epoch 00081: val_loss did not improve from 0.29807
# Epoch 82/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2031 - acc: 0.9321 - auc: 0.9922 - val_loss: 0.2993 - val_acc: 0.8804 - val_auc: 0.9835
#
# Epoch 00082: val_loss did not improve from 0.29807
# Epoch 83/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2192 - acc: 0.9295 - auc: 0.9902 - val_loss: 0.2991 - val_acc: 0.8804 - val_auc: 0.9836
#
# Epoch 00083: val_loss did not improve from 0.29807
# Epoch 84/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2094 - acc: 0.9298 - auc: 0.9920 - val_loss: 0.2992 - val_acc: 0.8809 - val_auc: 0.9836
#
# Epoch 00084: val_loss did not improve from 0.29807
# Epoch 85/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.1889 - acc: 0.9390 - auc: 0.9936 - val_loss: 0.2998 - val_acc: 0.8809 - val_auc: 0.9835
#
# Epoch 00085: val_loss did not improve from 0.29807
# Epoch 86/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.1987 - acc: 0.9371 - auc: 0.9924 - val_loss: 0.2989 - val_acc: 0.8804 - val_auc: 0.9837
#
# Epoch 00086: val_loss did not improve from 0.29807
# Epoch 87/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2146 - acc: 0.9288 - auc: 0.9912 - val_loss: 0.2991 - val_acc: 0.8799 - val_auc: 0.9836
#
# Epoch 00087: val_loss did not improve from 0.29807
# Epoch 88/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.2097 - acc: 0.9284 - auc: 0.9918 - val_loss: 0.2991 - val_acc: 0.8794 - val_auc: 0.9838
#
# Epoch 00088: val_loss did not improve from 0.29807
# Epoch 89/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.1978 - acc: 0.9352 - auc: 0.9927 - val_loss: 0.2993 - val_acc: 0.8799 - val_auc: 0.9835
#
# Epoch 00089: val_loss did not improve from 0.29807
# Epoch 90/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2184 - acc: 0.9270 - auc: 0.9907 - val_loss: 0.2996 - val_acc: 0.8813 - val_auc: 0.9835
#
# Epoch 00090: val_loss did not improve from 0.29807
# Epoch 91/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.2049 - acc: 0.9331 - auc: 0.9924 - val_loss: 0.2995 - val_acc: 0.8799 - val_auc: 0.9835
#
# Epoch 00091: val_loss did not improve from 0.29807
# Epoch 92/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.2069 - acc: 0.9335 - auc: 0.9918 - val_loss: 0.2987 - val_acc: 0.8813 - val_auc: 0.9837
#
# Epoch 00092: val_loss did not improve from 0.29807
# Epoch 93/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2042 - acc: 0.9316 - auc: 0.9924 - val_loss: 0.2990 - val_acc: 0.8804 - val_auc: 0.9836
#
# Epoch 00093: val_loss did not improve from 0.29807
# Epoch 94/100
# 256/256 [==============================] - 67s 263ms/step - loss: 0.1967 - acc: 0.9337 - auc: 0.9930 - val_loss: 0.2986 - val_acc: 0.8799 - val_auc: 0.9836
#
# Epoch 00094: val_loss did not improve from 0.29807
# Epoch 95/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.1963 - acc: 0.9359 - auc: 0.9932 - val_loss: 0.2986 - val_acc: 0.8799 - val_auc: 0.9837
#
# Epoch 00095: val_loss did not improve from 0.29807
# Epoch 96/100
# 256/256 [==============================] - 67s 264ms/step - loss: 0.2073 - acc: 0.9269 - auc: 0.9922 - val_loss: 0.2991 - val_acc: 0.8799 - val_auc: 0.9837
#
# Epoch 00096: val_loss did not improve from 0.29807
# Epoch 97/100
# 256/256 [==============================] - 68s 264ms/step - loss: 0.2134 - acc: 0.9302 - auc: 0.9910 - val_loss: 0.2982 - val_acc: 0.8799 - val_auc: 0.9836
#
# Epoch 00097: val_loss did not improve from 0.29807
# Epoch 98/100
# 256/256 [==============================] - 68s 266ms/step - loss: 0.2101 - acc: 0.9275 - auc: 0.9918 - val_loss: 0.2993 - val_acc: 0.8804 - val_auc: 0.9835
#
# Epoch 00098: val_loss did not improve from 0.29807
# Epoch 99/100
# 256/256 [==============================] - 68s 266ms/step - loss: 0.1928 - acc: 0.9427 - auc: 0.9930 - val_loss: 0.2992 - val_acc: 0.8813 - val_auc: 0.9835
#
# Epoch 00099: val_loss did not improve from 0.29807
# Epoch 100/100
# 256/256 [==============================] - 68s 265ms/step - loss: 0.2138 - acc: 0.9293 - auc: 0.9914 - val_loss: 0.2995 - val_acc: 0.8804 - val_auc: 0.9835
#
# Epoch 00100: val_loss did not improve from 0.29807

# %%
#Plotting the trend of the metrics during training
import seaborn as sns

fig, ax = plt.subplots(1, 3, figsize = (30, 5))
ax = ax.ravel()

for i, metric in enumerate(["acc", "auc", "loss"]):
    sns.set(font_scale=2)
    sns.set_style('whitegrid')
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %%
#Evaluating the model on the data

train_scores = DenseNet121_model.evaluate(train_data, train_labels)
val_scores = DenseNet121_model.evaluate(val_data, val_labels)
test_scores = DenseNet121_model.evaluate(test_data, test_labels)

print("Training Accuracy: %.2f%%"%(train_scores[1] * 100))
print("Validation Accuracy: %.2f%%"%(val_scores[1] * 100))
print("Testing Accuracy: %.2f%%"%(test_scores[1] * 100))
# Out:
# 256/256 [==============================] - 17s 65ms/step - loss: 0.1173 - acc: 0.9661 - auc: 0.9978
# 64/64 [==============================] - 4s 67ms/step - loss: 0.2995 - acc: 0.8804 - auc: 0.9835
# 80/80 [==============================] - 5s 66ms/step - loss: 0.3123 - acc: 0.8801 - auc: 0.9823
# Training Accuracy: 96.61%
# Validation Accuracy: 88.04%
# Testing Accuracy: 88.01%

# %%
#Predicting the test data

pred_labels = DenseNet121_model.predict(test_data)

#Print the classification report of the tested data

#Since the labels are softmax arrays, we need to roundoff to have it in the form of 0s and 1s,
#similar to the test_labels
def roundoff(arr):
    """To round off according to the argmax of each predicted label array. """
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

print(classification_report(test_labels, pred_labels, target_names=CLASSES))
# Out:
#                   precision    recall  f1-score   support
#
#      NonDemented       0.94      0.93      0.94       639
# VeryMildDemented       1.00      1.00      1.00       635
#     MildDemented       0.89      0.73      0.80       662
# ModerateDemented       0.72      0.86      0.78       624
#
#        micro avg       0.88      0.88      0.88      2560
#        macro avg       0.89      0.88      0.88      2560
#     weighted avg       0.89      0.88      0.88      2560
#      samples avg       0.88      0.88      0.88      2560

# %%
#Plot the confusion matrix to understand the classification in detail

pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(test_labels, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='YlGnBu', annot=True, fmt='d', xticklabels=CLASSES, yticklabels=CLASSES)

plt.title('Alzheimer\'s Disease Diagnosis')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)

# %%
# set plot figure size
from sklearn.preprocessing import LabelBinarizer

fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(test_labels)
    y_pred = lb.transform(pred_labels)

    for (idx, c_label) in enumerate(categories):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)

print('ROC AUC score:', multiclass_roc_auc_score(test_labels,pred_labels))

c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
plt.show()
# Out:
# ROC AUC score: 0.9208145730063182
