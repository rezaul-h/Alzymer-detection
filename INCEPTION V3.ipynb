# %%
# !pip install split-folders
# !pip install scikit-image
# !pip install keras-tuner
# Out:
# Requirement already satisfied: split-folders in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (0.5.1)
# Requirement already satisfied: scikit-image in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (0.19.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from scikit-image) (1.3.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from scikit-image) (9.0.1)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from scikit-image) (2021.11.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from scikit-image) (21.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from scikit-image) (1.7.3)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from scikit-image) (2.29.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from scikit-image) (1.19.2)
# Requirement already satisfied: networkx>=2.2 in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from scikit-image) (2.6.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from packaging>=20.0->scikit-image) (3.0.4)
# Requirement already satisfied: keras-tuner in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (1.3.5)
# Requirement already satisfied: packaging in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from keras-tuner) (21.3)
# Requirement already satisfied: requests in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from keras-tuner) (2.27.1)
# Requirement already satisfied: kt-legacy in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from packaging->keras-tuner) (3.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from requests->keras-tuner) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ovi\anaconda3\envs\tensrgpu\lib\site-packages (from requests->keras-tuner) (2021.10.8)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

import os
from distutils.dir_util import copy_tree, remove_tree

from PIL import Image
from random import randint

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import *
from sklearn.metrics import classification_report, confusion_matrix

# import tensorflow_addons as tfa
# from keras.utils.vis_utils import plot_model
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.callbacks import *
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.layers import SeparableConv2D, BatchNormalization, GlobalAveragePooling2D


print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.4.0

# %%
categories = ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

# %%
base_dir = "F:\\Ml files\\Alzymer detection/Alzheimer_s Dataset/"
root_dir = "./"
test_dir = base_dir + "test/"
train_dir = base_dir + "train/"
work_dir = root_dir + "dataset/"

if os.path.exists(work_dir):
    remove_tree(work_dir)
    

os.mkdir(work_dir)
copy_tree(train_dir, work_dir)
copy_tree(test_dir, work_dir)
print("Working Directory Contents:", os.listdir(work_dir))
# Out:
# Working Directory Contents: ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

# %%
WORK_DIR = './dataset/'

CLASSES = [ 'NonDemented',
            'VeryMildDemented',
            'MildDemented',
            'ModerateDemented']

IMG_SIZE = 176
IMAGE_SIZE = [176, 176]
DIM = (IMG_SIZE, IMG_SIZE)

# %%
#Performing Image Augmentation to have more data samples

ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

work_dr = IDG(rescale = 1./255, brightness_range=BRIGHT_RANGE, zoom_range=ZOOM, data_format=DATA_FORMAT, fill_mode=FILL_MODE, horizontal_flip=HORZ_FLIP)

train_data_gen = work_dr.flow_from_directory(directory=WORK_DIR, target_size=DIM, batch_size=6500, shuffle=False)
# Out:
# Found 6400 images belonging to 4 classes.

# %%
def show_images(generator,y_pred=None):
    """
    Input: An image generator,predicted labels (optional)
    Output: Displays a grid of 9 images with lables
    """
    
    # get image lables
    labels =dict(zip([0,1,2,3], CLASSES))
    
    # get a batch of images
    x,y = generator.next()
    
    # display a grid of 9 images
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 6400)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Class:{}".format(labels[np.argmax(y[idx])]))
                                                     
    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))
    
# Display Train Images
show_images(train_data_gen)

# %%
#Retrieving the data from the ImageDataGenerator iterator

train_data, train_labels = train_data_gen.next()

# %%
#Getting to know the dimensions of our dataset

print(train_data.shape, train_labels.shape)
# Out:
# (6400, 176, 176, 3) (6400, 4)

# %%
#Performing over-sampling of the data, since the classes are imbalanced

sm = SMOTE(random_state=42)

train_data, train_labels = sm.fit_resample(train_data.reshape(-1, IMG_SIZE * IMG_SIZE * 3), train_labels)

train_data = train_data.reshape(-1, IMG_SIZE, IMG_SIZE, 3)

print(train_data.shape, train_labels.shape)
# Out:
# (12800, 176, 176, 3) (12800, 4)

# %%
#Splitting the data into train, test, and validation sets

train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

# %%
inception_model = InceptionV3(input_shape=(176, 176, 3), include_top=False, weights="imagenet")
for layer in inception_model.layers:
    layer.trainable=False
custom_inception_model = Sequential([
        inception_model,
        Dropout(0.5),
        GlobalAveragePooling2D(),
        Flatten(),
        BatchNormalization(),
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(64, activation='relu'),
        Dropout(0.5),
        BatchNormalization(),
        Dense(4, activation='softmax')        
    ], name = "inception_cnn_model")

# %%
#Defining a custom callback function to stop training our model when accuracy goes above 99%

class MyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('acc') > 0.99:
            print("\nReached accuracy threshold! Terminating training.")
            self.model.stop_training = True
            
my_callback = MyCallback()

#ReduceLROnPlateau to stabilize the training process of the model
rop_callback = ReduceLROnPlateau(monitor="val_loss", patience=3)
checkpoint_path = 'F:\\Ml files\\Alzymer detection\\model\\kfold-inceptionv3-class_11.h5'
saved_model = ModelCheckpoint(monitor='val_loss', mode='min', filepath=checkpoint_path, verbose=1, save_best_only=True, save_weights_only=False)

# %%
METRICS = [tf.keras.metrics.CategoricalAccuracy(name='acc'),
           tf.keras.metrics.AUC(name='auc')]

CALLBACKS = [my_callback, rop_callback,saved_model]
    
custom_inception_model.compile(optimizer='rmsprop',
                              loss=tf.losses.CategoricalCrossentropy(),
                              metrics=METRICS)

custom_inception_model.summary()
# Out:
# Model: "inception_cnn_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 4, 4, 2048)        21802784
# _________________________________________________________________
# dropout (Dropout)            (None, 4, 4, 2048)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# batch_normalization_94 (Batc (None, 2048)              8192
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# batch_normalization_95 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_96 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_97 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# batch_normalization_98 (Batc (None, 64)                256
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 23,036,644
# Trainable params: 1,227,844
# Non-trainable params: 21,808,800
# _________________________________________________________________

# %%
#Fit the training data to the model and validate it using the validation data
EPOCHS = 100

history = custom_inception_model.fit(train_data, train_labels, validation_data=(val_data, val_labels), callbacks=CALLBACKS, epochs=EPOCHS)
# Out:
# Epoch 1/100
# 256/256 [==============================] - 29s 48ms/step - loss: 1.5959 - acc: 0.3426 - auc: 0.6003 - val_loss: 0.8197 - val_acc: 0.6187 - val_auc: 0.8749
#
# Epoch 00001: val_loss improved from inf to 0.81974, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 2/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.9915 - acc: 0.5439 - auc: 0.8209 - val_loss: 0.6708 - val_acc: 0.6831 - val_auc: 0.9164
#
# Epoch 00002: val_loss improved from 0.81974 to 0.67076, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 3/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.8279 - acc: 0.6276 - auc: 0.8750 - val_loss: 0.6332 - val_acc: 0.7090 - val_auc: 0.9248
#
# Epoch 00003: val_loss improved from 0.67076 to 0.63323, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 4/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.7793 - acc: 0.6570 - auc: 0.8917 - val_loss: 0.5794 - val_acc: 0.7354 - val_auc: 0.9371
#
# Epoch 00004: val_loss improved from 0.63323 to 0.57944, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 5/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.7109 - acc: 0.6774 - auc: 0.9077 - val_loss: 0.5494 - val_acc: 0.7520 - val_auc: 0.9446
#
# Epoch 00005: val_loss improved from 0.57944 to 0.54936, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 6/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.6798 - acc: 0.7017 - auc: 0.9180 - val_loss: 0.5389 - val_acc: 0.7612 - val_auc: 0.9465
#
# Epoch 00006: val_loss improved from 0.54936 to 0.53886, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 7/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.6227 - acc: 0.7197 - auc: 0.9293 - val_loss: 0.5010 - val_acc: 0.7803 - val_auc: 0.9544
#
# Epoch 00007: val_loss improved from 0.53886 to 0.50095, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 8/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.5797 - acc: 0.7549 - auc: 0.9398 - val_loss: 0.4647 - val_acc: 0.7925 - val_auc: 0.9604
#
# Epoch 00008: val_loss improved from 0.50095 to 0.46467, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 9/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.5785 - acc: 0.7652 - auc: 0.9415 - val_loss: 0.4818 - val_acc: 0.7925 - val_auc: 0.9574
#
# Epoch 00009: val_loss did not improve from 0.46467
# Epoch 10/100
# 256/256 [==============================] - 23s 89ms/step - loss: 0.5300 - acc: 0.7799 - auc: 0.9499 - val_loss: 0.4385 - val_acc: 0.8159 - val_auc: 0.9649
#
# Epoch 00010: val_loss improved from 0.46467 to 0.43846, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 11/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.5297 - acc: 0.7823 - auc: 0.9509 - val_loss: 0.4137 - val_acc: 0.8311 - val_auc: 0.9687
#
# Epoch 00011: val_loss improved from 0.43846 to 0.41372, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 12/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.4814 - acc: 0.8033 - auc: 0.9586 - val_loss: 0.4302 - val_acc: 0.8208 - val_auc: 0.9661
#
# Epoch 00012: val_loss did not improve from 0.41372
# Epoch 13/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.4721 - acc: 0.8130 - auc: 0.9604 - val_loss: 0.4058 - val_acc: 0.8394 - val_auc: 0.9698
#
# Epoch 00013: val_loss improved from 0.41372 to 0.40577, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 14/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.4709 - acc: 0.8171 - auc: 0.9608 - val_loss: 0.3662 - val_acc: 0.8423 - val_auc: 0.9753
#
# Epoch 00014: val_loss improved from 0.40577 to 0.36623, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 15/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.4243 - acc: 0.8351 - auc: 0.9679 - val_loss: 0.3763 - val_acc: 0.8418 - val_auc: 0.9739
#
# Epoch 00015: val_loss did not improve from 0.36623
# Epoch 16/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.4262 - acc: 0.8340 - auc: 0.9670 - val_loss: 0.3956 - val_acc: 0.8398 - val_auc: 0.9712
#
# Epoch 00016: val_loss did not improve from 0.36623
# Epoch 17/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.4047 - acc: 0.8484 - auc: 0.9704 - val_loss: 0.3506 - val_acc: 0.8564 - val_auc: 0.9772
#
# Epoch 00017: val_loss improved from 0.36623 to 0.35063, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 18/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.3872 - acc: 0.8528 - auc: 0.9729 - val_loss: 0.3386 - val_acc: 0.8638 - val_auc: 0.9784
#
# Epoch 00018: val_loss improved from 0.35063 to 0.33865, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 19/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.3723 - acc: 0.8609 - auc: 0.9752 - val_loss: 0.3184 - val_acc: 0.8701 - val_auc: 0.9810
#
# Epoch 00019: val_loss improved from 0.33865 to 0.31841, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 20/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.3552 - acc: 0.8689 - auc: 0.9771 - val_loss: 0.3269 - val_acc: 0.8677 - val_auc: 0.9800
#
# Epoch 00020: val_loss did not improve from 0.31841
# Epoch 21/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.3714 - acc: 0.8668 - auc: 0.9746 - val_loss: 0.3293 - val_acc: 0.8604 - val_auc: 0.9800
#
# Epoch 00021: val_loss did not improve from 0.31841
# Epoch 22/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.3343 - acc: 0.8742 - auc: 0.9794 - val_loss: 0.3274 - val_acc: 0.8623 - val_auc: 0.9802
#
# Epoch 00022: val_loss did not improve from 0.31841
# Epoch 23/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.3350 - acc: 0.8806 - auc: 0.9793 - val_loss: 0.3045 - val_acc: 0.8735 - val_auc: 0.9826
#
# Epoch 00023: val_loss improved from 0.31841 to 0.30447, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 24/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.3087 - acc: 0.8852 - auc: 0.9826 - val_loss: 0.2982 - val_acc: 0.8774 - val_auc: 0.9832
#
# Epoch 00024: val_loss improved from 0.30447 to 0.29815, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 25/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2768 - acc: 0.9007 - auc: 0.9857 - val_loss: 0.2957 - val_acc: 0.8740 - val_auc: 0.9835
#
# Epoch 00025: val_loss improved from 0.29815 to 0.29567, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 26/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2794 - acc: 0.9040 - auc: 0.9850 - val_loss: 0.2939 - val_acc: 0.8779 - val_auc: 0.9836
#
# Epoch 00026: val_loss improved from 0.29567 to 0.29388, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 27/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2814 - acc: 0.8970 - auc: 0.9853 - val_loss: 0.2959 - val_acc: 0.8809 - val_auc: 0.9836
#
# Epoch 00027: val_loss did not improve from 0.29388
# Epoch 28/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2582 - acc: 0.9081 - auc: 0.9876 - val_loss: 0.2921 - val_acc: 0.8789 - val_auc: 0.9839
#
# Epoch 00028: val_loss improved from 0.29388 to 0.29207, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 29/100
# 256/256 [==============================] - 11s 45ms/step - loss: 0.2760 - acc: 0.9016 - auc: 0.9854 - val_loss: 0.2920 - val_acc: 0.8818 - val_auc: 0.9840
#
# Epoch 00029: val_loss improved from 0.29207 to 0.29203, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 30/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2764 - acc: 0.9019 - auc: 0.9856 - val_loss: 0.2896 - val_acc: 0.8853 - val_auc: 0.9841
#
# Epoch 00030: val_loss improved from 0.29203 to 0.28956, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 31/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2507 - acc: 0.9090 - auc: 0.9875 - val_loss: 0.2904 - val_acc: 0.8809 - val_auc: 0.9840
#
# Epoch 00031: val_loss did not improve from 0.28956
# Epoch 32/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2476 - acc: 0.9139 - auc: 0.9880 - val_loss: 0.2928 - val_acc: 0.8809 - val_auc: 0.9842
#
# Epoch 00032: val_loss did not improve from 0.28956
# Epoch 33/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2626 - acc: 0.9020 - auc: 0.9867 - val_loss: 0.2917 - val_acc: 0.8804 - val_auc: 0.9842
#
# Epoch 00033: val_loss did not improve from 0.28956
# Epoch 34/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2465 - acc: 0.9109 - auc: 0.9881 - val_loss: 0.2910 - val_acc: 0.8813 - val_auc: 0.9843
#
# Epoch 00034: val_loss did not improve from 0.28956
# Epoch 35/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2735 - acc: 0.9059 - auc: 0.9857 - val_loss: 0.2899 - val_acc: 0.8823 - val_auc: 0.9843
#
# Epoch 00035: val_loss did not improve from 0.28956
# Epoch 36/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2629 - acc: 0.9078 - auc: 0.9867 - val_loss: 0.2882 - val_acc: 0.8818 - val_auc: 0.9845
#
# Epoch 00036: val_loss improved from 0.28956 to 0.28824, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 37/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2329 - acc: 0.9185 - auc: 0.9890 - val_loss: 0.2891 - val_acc: 0.8813 - val_auc: 0.9844
#
# Epoch 00037: val_loss did not improve from 0.28824
# Epoch 38/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2607 - acc: 0.9102 - auc: 0.9868 - val_loss: 0.2900 - val_acc: 0.8833 - val_auc: 0.9844
#
# Epoch 00038: val_loss did not improve from 0.28824
# Epoch 39/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2386 - acc: 0.9166 - auc: 0.9885 - val_loss: 0.2890 - val_acc: 0.8818 - val_auc: 0.9845
#
# Epoch 00039: val_loss did not improve from 0.28824
# Epoch 40/100
# 256/256 [==============================] - 11s 45ms/step - loss: 0.2439 - acc: 0.9158 - auc: 0.9883 - val_loss: 0.2882 - val_acc: 0.8833 - val_auc: 0.9845
#
# Epoch 00040: val_loss improved from 0.28824 to 0.28817, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 41/100
# 256/256 [==============================] - 11s 45ms/step - loss: 0.2432 - acc: 0.9139 - auc: 0.9886 - val_loss: 0.2898 - val_acc: 0.8809 - val_auc: 0.9844
#
# Epoch 00041: val_loss did not improve from 0.28817
# Epoch 42/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2485 - acc: 0.9137 - auc: 0.9875 - val_loss: 0.2889 - val_acc: 0.8823 - val_auc: 0.9845
#
# Epoch 00042: val_loss did not improve from 0.28817
# Epoch 43/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2476 - acc: 0.9110 - auc: 0.9882 - val_loss: 0.2893 - val_acc: 0.8813 - val_auc: 0.9844
#
# Epoch 00043: val_loss did not improve from 0.28817
# Epoch 44/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2488 - acc: 0.9141 - auc: 0.9877 - val_loss: 0.2889 - val_acc: 0.8818 - val_auc: 0.9845
#
# Epoch 00044: val_loss did not improve from 0.28817
# Epoch 45/100
# 256/256 [==============================] - 11s 45ms/step - loss: 0.2512 - acc: 0.9119 - auc: 0.9872 - val_loss: 0.2893 - val_acc: 0.8828 - val_auc: 0.9844
#
# Epoch 00045: val_loss did not improve from 0.28817
# Epoch 46/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2233 - acc: 0.9297 - auc: 0.9902 - val_loss: 0.2879 - val_acc: 0.8818 - val_auc: 0.9845
#
# Epoch 00046: val_loss improved from 0.28817 to 0.28790, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 47/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2485 - acc: 0.9122 - auc: 0.9876 - val_loss: 0.2886 - val_acc: 0.8833 - val_auc: 0.9844
#
# Epoch 00047: val_loss did not improve from 0.28790
# Epoch 48/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2646 - acc: 0.9064 - auc: 0.9860 - val_loss: 0.2898 - val_acc: 0.8804 - val_auc: 0.9844
#
# Epoch 00048: val_loss did not improve from 0.28790
# Epoch 49/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2627 - acc: 0.9053 - auc: 0.9863 - val_loss: 0.2897 - val_acc: 0.8809 - val_auc: 0.9843
#
# Epoch 00049: val_loss did not improve from 0.28790
# Epoch 50/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2363 - acc: 0.9157 - auc: 0.9892 - val_loss: 0.2895 - val_acc: 0.8813 - val_auc: 0.9844
#
# Epoch 00050: val_loss did not improve from 0.28790
# Epoch 51/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2516 - acc: 0.9072 - auc: 0.9878 - val_loss: 0.2906 - val_acc: 0.8828 - val_auc: 0.9843
#
# Epoch 00051: val_loss did not improve from 0.28790
# Epoch 52/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2313 - acc: 0.9164 - auc: 0.9899 - val_loss: 0.2904 - val_acc: 0.8828 - val_auc: 0.9843
#
# Epoch 00052: val_loss did not improve from 0.28790
# Epoch 53/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2509 - acc: 0.9092 - auc: 0.9876 - val_loss: 0.2910 - val_acc: 0.8823 - val_auc: 0.9843
#
# Epoch 00053: val_loss did not improve from 0.28790
# Epoch 54/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2330 - acc: 0.9167 - auc: 0.9894 - val_loss: 0.2892 - val_acc: 0.8818 - val_auc: 0.9844
#
# Epoch 00054: val_loss did not improve from 0.28790
# Epoch 55/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2332 - acc: 0.9207 - auc: 0.9891 - val_loss: 0.2906 - val_acc: 0.8838 - val_auc: 0.9843
#
# Epoch 00055: val_loss did not improve from 0.28790
# Epoch 56/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2448 - acc: 0.9136 - auc: 0.9884 - val_loss: 0.2899 - val_acc: 0.8828 - val_auc: 0.9844
#
# Epoch 00056: val_loss did not improve from 0.28790
# Epoch 57/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2587 - acc: 0.9110 - auc: 0.9869 - val_loss: 0.2890 - val_acc: 0.8828 - val_auc: 0.9845
#
# Epoch 00057: val_loss did not improve from 0.28790
# Epoch 58/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2505 - acc: 0.9142 - auc: 0.9874 - val_loss: 0.2877 - val_acc: 0.8823 - val_auc: 0.9846
#
# Epoch 00058: val_loss improved from 0.28790 to 0.28765, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 59/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2505 - acc: 0.9057 - auc: 0.9879 - val_loss: 0.2880 - val_acc: 0.8809 - val_auc: 0.9844
#
# Epoch 00059: val_loss did not improve from 0.28765
# Epoch 60/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2435 - acc: 0.9070 - auc: 0.9886 - val_loss: 0.2886 - val_acc: 0.8828 - val_auc: 0.9844
#
# Epoch 00060: val_loss did not improve from 0.28765
# Epoch 61/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2406 - acc: 0.9141 - auc: 0.9887 - val_loss: 0.2897 - val_acc: 0.8794 - val_auc: 0.9843
#
# Epoch 00061: val_loss did not improve from 0.28765
# Epoch 62/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2469 - acc: 0.9113 - auc: 0.9880 - val_loss: 0.2872 - val_acc: 0.8818 - val_auc: 0.9846
#
# Epoch 00062: val_loss improved from 0.28765 to 0.28722, saving model to F:\Ml files\Alzymer detection\model\kfold-inceptionv3-class_11.h5
# Epoch 63/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2574 - acc: 0.9048 - auc: 0.9872 - val_loss: 0.2887 - val_acc: 0.8828 - val_auc: 0.9845
#
# Epoch 00063: val_loss did not improve from 0.28722
# Epoch 64/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2758 - acc: 0.9025 - auc: 0.9856 - val_loss: 0.2920 - val_acc: 0.8813 - val_auc: 0.9843
#
# Epoch 00064: val_loss did not improve from 0.28722
# Epoch 65/100
# 256/256 [==============================] - 12s 45ms/step - loss: 0.2334 - acc: 0.9219 - auc: 0.9895 - val_loss: 0.2891 - val_acc: 0.8828 - val_auc: 0.9845
#
# Epoch 00065: val_loss did not improve from 0.28722
# Epoch 66/100
# 256/256 [==============================] - 11s 45ms/step - loss: 0.2424 - acc: 0.9183 - auc: 0.9878 - val_loss: 0.2887 - val_acc: 0.8828 - val_auc: 0.9845
#
# Epoch 00066: val_loss did not improve from 0.28722
# Epoch 67/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2413 - acc: 0.9146 - auc: 0.9881 - val_loss: 0.2897 - val_acc: 0.8813 - val_auc: 0.9844
#
# Epoch 00067: val_loss did not improve from 0.28722
# Epoch 68/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2627 - acc: 0.9046 - auc: 0.9868 - val_loss: 0.2883 - val_acc: 0.8823 - val_auc: 0.9845
#
# Epoch 00068: val_loss did not improve from 0.28722
# Epoch 69/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2293 - acc: 0.9202 - auc: 0.9896 - val_loss: 0.2878 - val_acc: 0.8833 - val_auc: 0.9845
#
# Epoch 00069: val_loss did not improve from 0.28722
# Epoch 70/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2288 - acc: 0.9184 - auc: 0.9900 - val_loss: 0.2887 - val_acc: 0.8833 - val_auc: 0.9843
#
# Epoch 00070: val_loss did not improve from 0.28722
# Epoch 71/100
# 256/256 [==============================] - 11s 45ms/step - loss: 0.2390 - acc: 0.9190 - auc: 0.9886 - val_loss: 0.2890 - val_acc: 0.8823 - val_auc: 0.9844
#
# Epoch 00071: val_loss did not improve from 0.28722
# Epoch 72/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2386 - acc: 0.9124 - auc: 0.9889 - val_loss: 0.2885 - val_acc: 0.8818 - val_auc: 0.9845
#
# Epoch 00072: val_loss did not improve from 0.28722
# Epoch 73/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2508 - acc: 0.9106 - auc: 0.9876 - val_loss: 0.2922 - val_acc: 0.8823 - val_auc: 0.9839
#
# Epoch 00073: val_loss did not improve from 0.28722
# Epoch 74/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2364 - acc: 0.9151 - auc: 0.9892 - val_loss: 0.2900 - val_acc: 0.8813 - val_auc: 0.9844
#
# Epoch 00074: val_loss did not improve from 0.28722
# Epoch 75/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2608 - acc: 0.9096 - auc: 0.9866 - val_loss: 0.2886 - val_acc: 0.8813 - val_auc: 0.9845
#
# Epoch 00075: val_loss did not improve from 0.28722
# Epoch 76/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2435 - acc: 0.9140 - auc: 0.9887 - val_loss: 0.2899 - val_acc: 0.8823 - val_auc: 0.9844
#
# Epoch 00076: val_loss did not improve from 0.28722
# Epoch 77/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2424 - acc: 0.9143 - auc: 0.9887 - val_loss: 0.2878 - val_acc: 0.8833 - val_auc: 0.9845
#
# Epoch 00077: val_loss did not improve from 0.28722
# Epoch 78/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2575 - acc: 0.9101 - auc: 0.9869 - val_loss: 0.2906 - val_acc: 0.8823 - val_auc: 0.9842
#
# Epoch 00078: val_loss did not improve from 0.28722
# Epoch 79/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2482 - acc: 0.9127 - auc: 0.9875 - val_loss: 0.2882 - val_acc: 0.8823 - val_auc: 0.9845
#
# Epoch 00079: val_loss did not improve from 0.28722
# Epoch 80/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2583 - acc: 0.9072 - auc: 0.9871 - val_loss: 0.2889 - val_acc: 0.8823 - val_auc: 0.9844
#
# Epoch 00080: val_loss did not improve from 0.28722
# Epoch 81/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2508 - acc: 0.9092 - auc: 0.9876 - val_loss: 0.2894 - val_acc: 0.8818 - val_auc: 0.9844
#
# Epoch 00081: val_loss did not improve from 0.28722
# Epoch 82/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2443 - acc: 0.9114 - auc: 0.9884 - val_loss: 0.2902 - val_acc: 0.8838 - val_auc: 0.9844
#
# Epoch 00082: val_loss did not improve from 0.28722
# Epoch 83/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2425 - acc: 0.9127 - auc: 0.9884 - val_loss: 0.2894 - val_acc: 0.8828 - val_auc: 0.9844
#
# Epoch 00083: val_loss did not improve from 0.28722
# Epoch 84/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2515 - acc: 0.9105 - auc: 0.9873 - val_loss: 0.2899 - val_acc: 0.8823 - val_auc: 0.9844
#
# Epoch 00084: val_loss did not improve from 0.28722
# Epoch 85/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2440 - acc: 0.9163 - auc: 0.9883 - val_loss: 0.2875 - val_acc: 0.8823 - val_auc: 0.9845
#
# Epoch 00085: val_loss did not improve from 0.28722
# Epoch 86/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2311 - acc: 0.9170 - auc: 0.9896 - val_loss: 0.2893 - val_acc: 0.8828 - val_auc: 0.9844
#
# Epoch 00086: val_loss did not improve from 0.28722
# Epoch 87/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2407 - acc: 0.9163 - auc: 0.9886 - val_loss: 0.2887 - val_acc: 0.8813 - val_auc: 0.9844
#
# Epoch 00087: val_loss did not improve from 0.28722
# Epoch 88/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2527 - acc: 0.9120 - auc: 0.9871 - val_loss: 0.2882 - val_acc: 0.8809 - val_auc: 0.9842
#
# Epoch 00088: val_loss did not improve from 0.28722
# Epoch 89/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2568 - acc: 0.9072 - auc: 0.9870 - val_loss: 0.2884 - val_acc: 0.8818 - val_auc: 0.9845
#
# Epoch 00089: val_loss did not improve from 0.28722
# Epoch 90/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2543 - acc: 0.9055 - auc: 0.9874 - val_loss: 0.2890 - val_acc: 0.8813 - val_auc: 0.9845
#
# Epoch 00090: val_loss did not improve from 0.28722
# Epoch 91/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2630 - acc: 0.9020 - auc: 0.9865 - val_loss: 0.2911 - val_acc: 0.8809 - val_auc: 0.9843
#
# Epoch 00091: val_loss did not improve from 0.28722
# Epoch 92/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2613 - acc: 0.9109 - auc: 0.9866 - val_loss: 0.2877 - val_acc: 0.8813 - val_auc: 0.9845
#
# Epoch 00092: val_loss did not improve from 0.28722
# Epoch 93/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2517 - acc: 0.9166 - auc: 0.9869 - val_loss: 0.2896 - val_acc: 0.8823 - val_auc: 0.9844
#
# Epoch 00093: val_loss did not improve from 0.28722
# Epoch 94/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2551 - acc: 0.9077 - auc: 0.9873 - val_loss: 0.2898 - val_acc: 0.8823 - val_auc: 0.9842
#
# Epoch 00094: val_loss did not improve from 0.28722
# Epoch 95/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2307 - acc: 0.9165 - auc: 0.9897 - val_loss: 0.2907 - val_acc: 0.8818 - val_auc: 0.9844
#
# Epoch 00095: val_loss did not improve from 0.28722
# Epoch 96/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2517 - acc: 0.9100 - auc: 0.9873 - val_loss: 0.2891 - val_acc: 0.8823 - val_auc: 0.9844
#
# Epoch 00096: val_loss did not improve from 0.28722
# Epoch 97/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2372 - acc: 0.9149 - auc: 0.9892 - val_loss: 0.2893 - val_acc: 0.8833 - val_auc: 0.9843
#
# Epoch 00097: val_loss did not improve from 0.28722
# Epoch 98/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2519 - acc: 0.9114 - auc: 0.9878 - val_loss: 0.2878 - val_acc: 0.8823 - val_auc: 0.9843
#
# Epoch 00098: val_loss did not improve from 0.28722
# Epoch 99/100
# 256/256 [==============================] - 11s 44ms/step - loss: 0.2480 - acc: 0.9129 - auc: 0.9877 - val_loss: 0.2890 - val_acc: 0.8828 - val_auc: 0.9845
#
# Epoch 00099: val_loss did not improve from 0.28722
# Epoch 100/100
# 256/256 [==============================] - 11s 43ms/step - loss: 0.2560 - acc: 0.9076 - auc: 0.9873 - val_loss: 0.2905 - val_acc: 0.8838 - val_auc: 0.9843
#
# Epoch 00100: val_loss did not improve from 0.28722

# %%
#Plotting the trend of the metrics during training
import seaborn as sns

fig, ax = plt.subplots(1, 3, figsize = (30, 5))
ax = ax.ravel()

for i, metric in enumerate(["acc", "auc", "loss"]):
    sns.set(font_scale=2)
    sns.set_style('whitegrid')
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %%
#Evaluating the model on the data

train_scores = custom_inception_model.evaluate(train_data, train_labels)
val_scores = custom_inception_model.evaluate(val_data, val_labels)
test_scores = custom_inception_model.evaluate(test_data, test_labels)

print("Training Accuracy: %.2f%%"%(train_scores[1] * 100))
print("Validation Accuracy: %.2f%%"%(val_scores[1] * 100))
print("Testing Accuracy: %.2f%%"%(test_scores[1] * 100))
# Out:
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0641 - acc: 0.9860 - auc: 0.9995
# 64/64 [==============================] - 2s 34ms/step - loss: 0.2905 - acc: 0.8838 - auc: 0.9843
# 80/80 [==============================] - 3s 32ms/step - loss: 0.3333 - acc: 0.8703 - auc: 0.9812
# Training Accuracy: 98.60%
# Validation Accuracy: 88.38%
# Testing Accuracy: 87.03%

# %%
#Predicting the test data

pred_labels = custom_inception_model.predict(test_data)

#Print the classification report of the tested data

#Since the labels are softmax arrays, we need to roundoff to have it in the form of 0s and 1s,
#similar to the test_labels
def roundoff(arr):
    """To round off according to the argmax of each predicted label array. """
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

print(classification_report(test_labels, pred_labels, target_names=CLASSES))
# Out:
#                   precision    recall  f1-score   support
#
#      NonDemented       0.89      0.94      0.91       639
# VeryMildDemented       1.00      1.00      1.00       635
#     MildDemented       0.86      0.72      0.79       662
# ModerateDemented       0.74      0.83      0.78       624
#
#        micro avg       0.87      0.87      0.87      2560
#        macro avg       0.87      0.87      0.87      2560
#     weighted avg       0.87      0.87      0.87      2560
#      samples avg       0.87      0.87      0.87      2560

# %%
#Plot the confusion matrix to understand the classification in detail

pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(test_labels, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='YlGnBu', annot=True, fmt='d', xticklabels=CLASSES, yticklabels=CLASSES)

plt.title('Alzheimer\'s Disease Diagnosis')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)

# %%
# set plot figure size
from sklearn.preprocessing import LabelBinarizer

fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(test_labels)
    y_pred = lb.transform(pred_labels)

    for (idx, c_label) in enumerate(categories):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)

print('ROC AUC score:', multiclass_roc_auc_score(test_labels,pred_labels))

c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
plt.show()
# Out:
# ROC AUC score: 0.9142375878571987
